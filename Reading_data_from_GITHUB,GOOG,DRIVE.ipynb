# %% [markdown]
# <a href="https://colab.research.google.com/github/khaledn66/pyspark2/blob/main/Reading_data_from_GITHUB%2CGOOG%2CDRIVE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Read Write and validate code along acivites **

# %% [markdown]
# **Rading Data **

# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("FirstSpark").getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://a1093e4a040e:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>FirstSpark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
core = spark._jsc.sc().getExecutorMemoryStatus().keySet().size()
core
# Out:
# 1

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print(current_directory)
#from google.colab import drive
#drive.mount('/content/drive',force_remount=True)
file_path = "./sample_data/students.csv"
students = spark.read.csv(file_path, inferSchema=True, header=True)
students.show(5)
# Out:
# /content
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <ipython-input-8-56aae5c0f917> in <cell line: 9>()
#       7 #drive.mount('/content/drive',force_remount=True)
#       8 file_path = "./sample_data/students.csv"
# ----> 9 students = spark.read.csv(file_path, inferSchema=True, header=True)
#      10 students.show(5)
#
# ...

# %%
import os

# List all files in the current working directory
for dirname, _, filenames in os.walk('.'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./.config/.last_update_check.json
# ./.config/.last_opt_in_prompt.yaml
# ./.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
# ./.config/default_configs.db
# ./.config/config_sentinel
# ./.config/gce
# ./.config/.last_survey_prompt.yaml
# ./.config/active_config
# ./.config/logs/2024.10.29/13.25.18.421638.log
# ./.config/logs/2024.10.29/13.25.05.013433.log
# ./.config/logs/2024.10.29/13.25.06.326630.log
# ./.config/logs/2024.10.29/13.25.19.100580.log
# ./.config/logs/2024.10.29/13.24.52.597697.log
# ./.config/logs/2024.10.29/13.24.30.264802.log
# ./.config/configurations/config_default
# ./sample_data/README.md
# ./sample_data/anscombe.json
# ./sample_data/students.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv
# ./sample_data/mnist_test.csv

# %% [markdown]
# **download Files from google drive **

# %%
from google.colab import files

# Download the file
files.download('./sample_data/students.csv')

# %% [markdown]
# **1.Mount Google Drive **

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/My Drive/content/students.csv'
students = spark.read.csv(file_path, inferSchema=True, header=True)
students.show(5)
# Out:
# +------+--------------+---------------------------+------------+-----------------------+----------+-------------+-------------+
# |gender|race/ethnicity|parental level of education|       lunch|test preparation course|math score|reading score|writing score|
# +------+--------------+---------------------------+------------+-----------------------+----------+-------------+-------------+
# |female|       group B|          bachelor's degree|    standard|                   none|        72|           72|           74|
# |female|       group C|               some college|    standard|              completed|        69|           90|           88|
# |female|       group B|            master's degree|    standard|                   none|        90|           95|           93|
# |  male|       group A|         associate's degree|free/reduced|                   none|        47|           57|           44|
# ...

# %% [markdown]
# **Cloning a GitHub Repository**

# %%
#!git clone https://github.com/username/repository.git
# !git clone https://github.com/khaled66/pyspark2.git
# Out:
# Cloning into 'pyspark2'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git clone https://github.com/khaledn66/pyspark2.git
# Out:
# Cloning into 'pyspark2'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 23 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 95.05 KiB | 5.94 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# !ls pyspark2
# Out:
# _aggregating_dataframes_code_along_checkpoint_ipynb.ipynb  LICENSE    students.csv
# gitignore						   README.md  UDF.ipynb

# %% [markdown]
# # Новый раздел

# %%
file_path = './pyspark2/students.csv'
students = spark.read.csv(file_path, inferSchema=True, header=True)
students.show(5)
# Out:
# +------+--------------+---------------------------+------------+-----------------------+----------+-------------+-------------+
# |gender|race/ethnicity|parental level of education|       lunch|test preparation course|math score|reading score|writing score|
# +------+--------------+---------------------------+------------+-----------------------+----------+-------------+-------------+
# |female|       group B|          bachelor's degree|    standard|                   none|        72|           72|           74|
# |female|       group C|               some college|    standard|              completed|        69|           90|           88|
# |female|       group B|            master's degree|    standard|                   none|        90|           95|           93|
# |  male|       group A|         associate's degree|free/reduced|                   none|        47|           57|           44|
# ...

# %%
students.limit(5).toPandas()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
file_path='./pyspark2/users1.parquet'
parquet= spark.read.parquet(file_path, inferSchema=True, header=True)
parquet.limit(4).show()
# Out:
# +-------------------+---+----------+---------+--------------------+------+--------------+----------------+---------+---------+---------+--------------------+--------+
# |  registration_dttm| id|first_name|last_name|               email|gender|    ip_address|              cc|  country|birthdate|   salary|               title|comments|
# +-------------------+---+----------+---------+--------------------+------+--------------+----------------+---------+---------+---------+--------------------+--------+
# |2016-02-03 07:55:29|  1|    Amanda|   Jordan|    ajordan0@com.com|Female|   1.197.201.2|6759521864920116|Indonesia| 3/8/1971| 49756.53|    Internal Auditor|   1E+02|
# |2016-02-03 17:04:03|  2|    Albert|  Freeman|     afreeman1@is.gd|  Male|218.111.175.34|                |   Canada|1/16/1968|150280.17|       Accountant IV|        |
# ...

# %% [markdown]
# **Read Parquet file **

# %% [markdown]
# f you've added a new file to your GitHub repository after initially cloning it into Colab, you’ll need to update the local copy in Colab to include the latest changes. Here’s how to do that:
# # *1. Navigate to the Cloned Repository Directory**

# %%
# %cd pyspark2
# Out:
# /content/pyspark2

# %% [markdown]
# # 2. Pull the Latest Changes
# Use git pull to fetch and merge the latest changes from GitHub into your local repository:

# %%
# !git pull
# Out:
# Already up to date.

# %% [markdown]
# # 3. Verify the File is Now Visible

# %%
# !ls
# Out:
# _aggregating_dataframes_code_along_checkpoint_ipynb.ipynb  README.md	 users1.parquet
# gitignore						   students.csv  users2.parquet
# LICENSE							   UDF.ipynb	 users3.parquet

# %%
file_path='./pyspark2/users1.parquet'
parquet= spark.read.parquet(file_path, inferSchema=True, header=True)
parquet.limit(4).toPandas()
# Out:
#     registration_dttm  id first_name last_name                    email  \
# 0 2016-02-03 07:55:29   1     Amanda    Jordan         ajordan0@com.com
# 1 2016-02-03 17:04:03   2     Albert   Freeman          afreeman1@is.gd
# 2 2016-02-03 01:09:31   3     Evelyn    Morgan  emorgan2@altervista.org
# 3 2016-02-03 00:36:21   4     Denise     Riley         driley3@gmpg.org
#
#    gender      ip_address                cc    country  birthdate     salary  \
# 0  Female     1.197.201.2  6759521864920116  Indonesia   3/8/1971   49756.53
# 1    Male  218.111.175.34                       Canada  1/16/1968  150280.17
# 2  Female    7.161.136.94  6767119071901597     Russia   2/1/1960  144972.51
# 3  Female   140.35.109.83  3576031598965625      China   4/8/1997   90263.05
#
#                     title comments
# 0        Internal Auditor    1E+02
# 1           Accountant IV
# 2     Structural Engineer
# 3  Senior Cost Accountant

# %% [markdown]
# **READ  Data from 3 files .parquet **

# %%
file_path="./pyspark2/"
partioned= spark.read.parquet(file_path+"users*", inferSchema=True, header=True)
partioned.limit(4).toPandas()
# Out:
#     registration_dttm  id first_name last_name                    email  \
# 0 2016-02-03 07:55:29   1     Amanda    Jordan         ajordan0@com.com
# 1 2016-02-03 17:04:03   2     Albert   Freeman          afreeman1@is.gd
# 2 2016-02-03 01:09:31   3     Evelyn    Morgan  emorgan2@altervista.org
# 3 2016-02-03 00:36:21   4     Denise     Riley         driley3@gmpg.org
#
#    gender      ip_address                cc    country  birthdate     salary  \
# 0  Female     1.197.201.2  6759521864920116  Indonesia   3/8/1971   49756.53
# 1    Male  218.111.175.34                       Canada  1/16/1968  150280.17
# 2  Female    7.161.136.94  6767119071901597     Russia   2/1/1960  144972.51
# 3  Female   140.35.109.83  3576031598965625      China   4/8/1997   90263.05
#
#                     title comments
# 0        Internal Auditor    1E+02
# 1           Accountant IV
# 2     Structural Engineer
# 3  Senior Cost Accountant

# %%
partioned= spark.read.parquet(file_path+"users1.parquet",file_path+"users2.parquet", inferSchema=True, header=True)
partioned.limit(4).toPandas()
# Out:
#     registration_dttm  id first_name last_name                    email  \
# 0 2016-02-03 07:55:29   1     Amanda    Jordan         ajordan0@com.com
# 1 2016-02-03 17:04:03   2     Albert   Freeman          afreeman1@is.gd
# 2 2016-02-03 01:09:31   3     Evelyn    Morgan  emorgan2@altervista.org
# 3 2016-02-03 00:36:21   4     Denise     Riley         driley3@gmpg.org
#
#    gender      ip_address                cc    country  birthdate     salary  \
# 0  Female     1.197.201.2  6759521864920116  Indonesia   3/8/1971   49756.53
# 1    Male  218.111.175.34                       Canada  1/16/1968  150280.17
# 2  Female    7.161.136.94  6767119071901597     Russia   2/1/1960  144972.51
# 3  Female   140.35.109.83  3576031598965625      China   4/8/1997   90263.05
#
#                     title comments
# 0        Internal Auditor    1E+02
# 1           Accountant IV
# 2     Structural Engineer
# 3  Senior Cost Accountant

# %%
partioned= spark.read.option("bathPath",file_path).parquet(file_path+"users1.parquet",file_path+"users2.parquet", inferSchema=True, header=True)
partioned.limit(4).toPandas()
# Out:
#     registration_dttm  id first_name last_name                    email  \
# 0 2016-02-03 07:55:29   1     Amanda    Jordan         ajordan0@com.com
# 1 2016-02-03 17:04:03   2     Albert   Freeman          afreeman1@is.gd
# 2 2016-02-03 01:09:31   3     Evelyn    Morgan  emorgan2@altervista.org
# 3 2016-02-03 00:36:21   4     Denise     Riley         driley3@gmpg.org
#
#    gender      ip_address                cc    country  birthdate     salary  \
# 0  Female     1.197.201.2  6759521864920116  Indonesia   3/8/1971   49756.53
# 1    Male  218.111.175.34                       Canada  1/16/1968  150280.17
# 2  Female    7.161.136.94  6767119071901597     Russia   2/1/1960  144972.51
# 3  Female   140.35.109.83  3576031598965625      China   4/8/1997   90263.05
#
#                     title comments
# 0        Internal Auditor    1E+02
# 1           Accountant IV
# 2     Structural Engineer
# 3  Senior Cost Accountant
